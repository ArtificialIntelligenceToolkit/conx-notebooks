# %% [markdown]
# # Calysto Scheme
#
# Calysto Scheme is a full Scheme language, written in Scheme. It is then transpiled into Python.
#
# It can do normal things:

# %%
(+ 1 1)
# Out:
# 2

# %%
(lambda (x) 
  (+ 1 x))
# Out:
# #<procedure>

# %% [markdown]
# But it can also take advantage of Jupyter, where the name \lambda (shown as λ) is an alias for `lambda`:

# %%
(λ (x) (+ 1 x))
# Out:
# #<procedure>

# %% [markdown]
# It also has a virtual stack, to help with debugging:

# %%
(define fact
    (lambda (n)
      (if (= n 1)
           q
           (* n (fact (- n 1))))))
(fact 5)
# Out:
# Traceback (most recent call last):
#   File "In [4]", line 6, col 1, in 'fact'
#   File "In [4]", line 5, col 17, in 'fact'
#   File "In [4]", line 5, col 17, in 'fact'
#   File "In [4]", line 5, col 17, in 'fact'
#   File "In [4]", line 5, col 17, in 'fact'
#   File "In [4]", line 4, col 12
# RunTimeError: unbound variable 'q'

# %%
%%debug

(begin
    (define fact
        (lambda (n)
          (if (= n 1)
               q
               (* n (fact (- n 1))))))
    (fact 5)
)
# Out:
# <style type="text/css">
#       .breakpoints {width: 1.5em;}
#       .styled-background { background-color: #ff7; }
# </style>
#
# <div class="animation" align="left" width="400">
#   <button onclick="step()">Step</button>
#   <button onclick="play()">Play</button>
#   <button onclick="pause()">Pause</button>
#   <button onclick="stop()">Stop</button>
#   <button onclick="clear_breakpoints()">Clear Breakpoints</button>
#   <button onclick="reset()">Reset</button><br/>
#   Speed: <input type="range" id="speed" min="1" max="100"/>
#   Inspect: <input type="text" id="inspect" onkeydown="if (event.keyCode == 13) inspector()"/>
#   <table width="100%">
#   <tr>
#     <td width="50%" style="vertical-align: top"><div id="result_stream"/></td>
#     <td width="50%" style="vertical-align: top"><div id="result_output"/></td>
#   </tr>
#   </table>
# </div>
#
# <script>
#
# function inspector() {
#     var v = document.getElementById("inspect").value;
# ...

# %% [markdown]
# ## Standard Magics

# %%
(define upper (lambda (s) (s.upper)))
(define split (lambda (s) (string->list s)))

# %%
(upper "hello")
(split "hello")
# Out:
# (#\h #\e #\l #\l #\o)

# %%
%%pipe upper | split

"this is a test"
# Out:
# (#\newline #\" #\T #\H #\I #\S #\space #\I #\S #\space #\A #\space #\T #\E #\S #\T #\")

# %% [markdown]
# ## Deep Learning in Scheme
#
# Calysto Scheme can import Python libraries, like conx:

# %%
(import-as "conx" "cx")
# Out:
# (cx)

# %%
(define net (cx.Network "XOR" 2 2 1 (activation : "sigmoid")))
(net.compile (error : "mse") (optimizer : "adam"))

# %%
(net.picture '[-1 1] (dynamic : #t))
# Out:
# <svg id='XOR' xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' image-rendering="pixelated" width="384.61538461538464px" height="400.0px">
#  <g >
#   <svg viewBox="0 0 250 260" width="384.61538461538464px" height="400.0px">
#     <defs>
#         <marker id="arrow" markerWidth="10" markerHeight="10" refX="9" refY="3" orient="auto" markerUnits="strokeWidth">
#           <path d="M0,0 L0,6 L9,3 z" fill="black" />
#         </marker>
#     </defs><rect x="99.0" y="24" width="52" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="XOR_output_1" class="XOR_output" x="100.0" y="25" height="50" width="50" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output (output)
#  output range: (0, 1)
#  shape = (1,)
#  Keras class = Dense
# ...

# %%
(net.propagate '[1 -1] (update_pictures : #t))
# Out:
# #1(0.7529910802841187)

# %% [markdown]
# It can easily handle very large networks, like VGG16 that has over 138 million weights, even without a GPU:

# %%
(define vgg16 (cx.Network.get "vgg16"))

# %% [markdown]
# Here is a picture of a dog:

# %%
(cx.image "dog.jpg" (resize : '(224 224)))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFD345C1048>

# %% [markdown]
# What does the network think it is?

# %%
(vgg16.postprocess 
  (vgg16.propagate 
    (vgg16.preprocess 
      (cx.image_to_array 
        (cx.image "dog.jpg" (resize : '(224 224)))))) 1)
# Out:
# #1(('n02100236', 'German_short-haired_pointer', 0.6061604619026184))

# %% [markdown]
# Here is a picture of a geyser:

# %%
(cx.image "geyser.jpg" (resize : '(224 224)))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFD1A5D3668>

# %% [markdown]
# What does the network think it is?

# %%
(vgg16.postprocess 
  (vgg16.propagate 
    (vgg16.preprocess 
      (cx.image_to_array 
        (cx.image "geyser.jpg" (resize : '(224 224)))))) 1)
# Out:
# #1(('n09288635', 'geyser', 0.7626754641532898))
