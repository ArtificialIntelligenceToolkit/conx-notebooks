# %% [markdown]
# # Variational Auto-Encoder
#
# Work in progress.

# %%
import conx as cx
import keras.backend as K

# %% [markdown]
# We need a function to use as the activation function for the Sampler layer:

# %%
LENGTH = 5 # latent size

# %%
def sampler(inputs):
    ## inputs is a merged concat
    mean, stddev = inputs[:, :LENGTH], inputs[:, LENGTH:]
    # we sample from the standard normal a matrix of batch_size * latent_size (taking into account minibatches)
    std_norm = K.random_normal(shape=(K.shape(mean)[0], LENGTH), mean=0, stddev=1)
    # sampling from Z~N(μ, σ^2) is the same as sampling from μ + σX, X~N(0,1)
    return mean + K.exp(stddev) * std_norm

# %%
net = cx.Network("vae")

# %%
net.add(cx.Layer("input", 2),
        cx.Layer("hidden", 5),
        cx.Layer("mean", LENGTH),
        cx.Layer("stddev", LENGTH),
        cx.LambdaLayer("encode", sampler), # function, that takes input layer's output
        cx.Layer("output", 2));

# %%
net.connect("input", "hidden")
net.connect("hidden", "mean")
net.connect("hidden", "stddev")
net.connect("mean", "encode")
net.connect("stddev", "encode")
net.connect("encode", "output")

# %% [markdown]
# To allow an additional error function, we need to declare "encode" (an internal bank) as an output:

# %%
net.additional_output_banks = ["encode"]

# %% [markdown]
# And then we can provide a dictionary of error functions by name:

# %%
net.compile(error={"output": "mse", "encode": "mse"}, optimizer="adam")

# %%
net.picture([1,-1])
# Out:
# <svg id='vae' xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' image-rendering="pixelated" width="400.0px" height="240.0px">
#  <g >
#   <svg viewBox="0 0 700 420" width="400.0px" height="240.0px">
#     <defs>
#         <marker id="arrow" markerWidth="10" markerHeight="10" refX="9" refY="3" orient="auto" markerUnits="strokeWidth">
#           <path d="M0,0 L0,6 L9,3 z" fill="black" />
#         </marker>
#     </defs><rect x="299.0" y="24" width="102" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="picture-static-vae-275708_output_1" class="picture-static-vae-275708_output" x="300.0" y="25" height="50" width="100" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output (output)
#  output range: (-Infinity, +Infinity)
#  shape = (2,)
#  Keras class = Dense</title><text x="405.0" y="52.0" font-family="monospace" font-size="12" text-anchor="start" fill="black" alignment-baseline="central" >output</text><line x1="350.0" y1="104" x2="350.0" y2="77" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from encode to output
#  output_4/kernel:0 has shape (5, 2)
#  output_4/bias:0 has shape (2,)</title></line><rect x="249.0" y="104" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="picture-static-vae-275708_encode_2" class="picture-static-vae-275708_encode" x="250.0" y="105" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: encode (hidden)
#  output range: (-Infinity, +Infinity)
#  Keras class = Lambda</title><text x="455.0" y="132.0" font-family="monospace" font-size="12" text-anchor="start" fill="black" alignment-baseline="central" >encode</text><line x1="233.33333333333334" y1="184" x2="350.0" y2="157" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from mean to encode</title></line><rect x="132.33333333333334" y="184" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="picture-static-vae-275708_mean_3" class="picture-static-vae-275708_mean" x="133.33333333333334" y="185" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: mean (hidden)
#  output range: (-Infinity, +Infinity)
#  shape = (5,)
#  Keras class = Dense</title><text x="338.33333333333337" y="212.0" font-family="monospace" font-size="12" text-anchor="start" fill="black" alignment-baseline="central" >mean</text><line x1="466.6666666666667" y1="184" x2="350.0" y2="157" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from stddev to encode</title></line><rect x="365.6666666666667" y="184" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="picture-static-vae-275708_stddev_4" class="picture-static-vae-275708_stddev" x="366.6666666666667" y="185" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: stddev (hidden)
#  output range: (-Infinity, +Infinity)
#  shape = (5,)
#  Keras class = Dense</title><text x="571.6666666666667" y="212.0" font-family="monospace" font-size="12" text-anchor="start" fill="black" alignment-baseline="central" >stddev</text><line x1="350.0" y1="264" x2="233.33333333333334" y2="237" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from hidden to mean
#  mean_16/kernel:0 has shape (5, 5)
#  mean_16/bias:0 has shape (5,)</title></line><line x1="350.0" y1="264" x2="466.6666666666667" y2="237" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from hidden to stddev
#  stddev_16/kernel:0 has shape (5, 5)
#  stddev_16/bias:0 has shape (5,)</title></line><rect x="249.0" y="264" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="picture-static-vae-275708_hidden_5" class="picture-static-vae-275708_hidden" x="250.0" y="265" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: hidden (hidden)
#  output range: (-Infinity, +Infinity)
#  shape = (5,)
#  Keras class = Dense</title><text x="455.0" y="292.0" font-family="monospace" font-size="12" text-anchor="start" fill="black" alignment-baseline="central" >hidden</text><line x1="350.0" y1="344" x2="350.0" y2="317" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from input to hidden
#  hidden_20/kernel:0 has shape (2, 5)
#  hidden_20/bias:0 has shape (5,)</title></line><rect x="299.0" y="344" width="102" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="picture-static-vae-275708_input_6" class="picture-static-vae-275708_input" x="300.0" y="345" height="50" width="100" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: input (input)
#  output range: (-1, 1)
#  shape = (2,)
#  Keras class = Input</title><text x="405.0" y="372.0" font-family="monospace" font-size="12" text-anchor="start" fill="black" alignment-baseline="central" >input</text><text x="350.0" y="12.5" font-family="monospace" font-size="15" text-anchor="middle" fill="black" alignment-baseline="central" >vae</text></svg></g></svg>

# %%
net.propagate_to("encode", [1,-1])
# Out:
# [0.7351282238960266,
#  5.082088470458984,
#  0.5933042168617249,
#  -2.287989854812622,
#  -1.0812584161758423]

# %% [markdown]
# CAPACITY used to break input down to a set number of basis.
#
# BETA (> 1) used for latent regularizer.

# %%
CAPACITY = 32
BETA = 1.5

def bvae_loss(targets, outputs):
    mean, stddev = outputs[:LENGTH], outputs[LENGTH:]
    # kl divergence:
    latent_loss = -0.5 * K.mean(1 + stddev
                        - K.square(mean)
                        - K.exp(stddev), axis=-1)
    # use beta to force less usage of vector space:
    # also try to use <capacity> dimensions of the space:
    latent_loss = BETA * K.abs(latent_loss - CAPACITY/LENGTH)
    return latent_loss

def vae_loss(targets, outputs):
    mean, stddev = outputs[:LENGTH], outputs[LENGTH:]
    # kl divergence:
    latent_loss = -0.5 * K.mean(1 + stddev
                        - K.square(mean)
                        - K.exp(stddev), axis=-1)
    return latent_loss

# %%
net.compile(error={"output": "mse", "encode": vae_loss}, optimizer="adam")

# %%
net.compile(error={"output": "mse", "encode": bvae_loss}, optimizer="adam")
